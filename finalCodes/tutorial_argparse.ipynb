# %%
import argparse

parser = argparse.ArgumentParse()
args = paraser.parase_args("")

print(args)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-c712c282ed0d> in <module>()
#       1 import argparse
#       2
# ----> 3 parser = argparse.ArgumentParse()
#       4 args = paraser.parase_args("")
#       5
#
# AttributeError: module 'argparse' has no attribute 'ArgumentParse'
